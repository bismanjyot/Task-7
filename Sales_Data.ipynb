-- %%
%CREATE sales_data.db

-- %%
CREATE TABLE Sales(
  Customer_ID INT PRIMARY KEY,
  Customer VARCHAR(50),
  Mode VARCHAR(50),
  City VARCHAR(50),
  Item VARCHAR(50),
  Price INT
);

-- %%
INSERT INTO Sales VALUES
(101,"Olivia Barrett","Netbanking","Portland","Phone",50000),
(102,"Ethan Sinclair","Credit Card","Miami","Laptop",90000),
(103,"Maya Hernandez","Credit Card","Seattle","T.V.",85000),
(104,"Liam Donovan","Netbanking","Denver","Refrigerator",150000),
(105,"Sophia Nguyen","Credit Card","New Orleans","IPAD",30000),
(106,"Caleb Foster","Debit Card","Minneapolis","Iphone",65000),
(107,"Ava Patel","Debit Card","Phoenix","Tablet",25000),
(108,"Lucas Carter","Netbanking","Boston","Alexa",46000),
(109,"Isabella Martinez","Netbanking","Nashville","Sofa",75000),
(110,"Jackson Brooks","Credit Card","Boston","Bed",20000);

-- %%
SELECT * FROM Sales
-- Out:
-- +-------------+-------------------+-------------+-------------+--------------+--------+
-- | Customer_ID | Customer          | Mode        | City        | Item         | Price  |
-- +-------------+-------------------+-------------+-------------+--------------+--------+
-- | 101         | Olivia Barrett    | Netbanking  | Portland    | Phone        | 50000  |
-- +-------------+-------------------+-------------+-------------+--------------+--------+
-- | 102         | Ethan Sinclair    | Credit Card | Miami       | Laptop       | 90000  |
-- +-------------+-------------------+-------------+-------------+--------------+--------+
-- | 103         | Maya Hernandez    | Credit Card | Seattle     | T.V.         | 85000  |
-- +-------------+-------------------+-------------+-------------+--------------+--------+
-- | 104         | Liam Donovan      | Netbanking  | Denver      | Refrigerator | 150000 |
-- ...
